# %%
import spacy, os
import pandas as pd
import numpy as np
import en_core_web_sm
nlp = en_core_web_sm.load()
import re
re_c = re.compile(r'\w+')

# %%
# switch for debug
flag_print = True

# switch to clear existing data
flag_clear = True

#threshold value for determining section
threshold = 0.5

# %%
# to get extract sections from the resume -- add or remove from  'similar_to' accordingly
similar_to = {
    'edu' : ['education', 'study', 'academics', 'institute', 'school', 'college'],
    'exp' : ['job', 'internship', 'training', 'research', 'carrer', 'profession', 'role'
             'project', 'responsibility', 'description', 'work experience', 'workshop', 'conference'],
    'skill' : ['skill', 'languages', 'technology', 'framework', 'tools', 'database'],
    'extra' : ['introduction', 'intro', 'achievement', 'hobby', 'links', 'additional', 
               'personal', 'award', 'objective', 'miscellaneous', 'interest']
}

list_of_sections = similar_to.keys()

# to bring similar_words to their normal forms
for section in list_of_sections:
    new_list = []
    
    for word in similar_to[section]:
        docx = nlp(unicode(word))
        new_list.append(docx[0].lemma_)
        
    if flag_print:
        print section, new_list
        
    similar_to[section] = new_list
# Out:
# skill [u'skill', u'language', u'technology', u'framework', u'tool', u'database']
# extra [u'introduction', u'intro', u'achievement', u'hobby', u'link', u'additional', u'personal', u'award', u'objective', u'miscellaneous', u'interest']
# exp [u'job', u'internship', u'training', u'research', u'carrer', u'profession', u'roleproject', u'responsibility', u'description', u'work', u'workshop', u'conference']
# edu [u'education', u'study', u'academic', u'institute', u'school', u'college']

# %%
# function to return the words in a uniform 
def modify(word):
    try:
        symbols = '''~'`!@#$%^&*)(_+-=}{][|\:;",./<>?'''
        mod_word = ''
        
        for char in word:
            if (char not in symbols):
                mod_word += char.lower()

        docx = nlp(unicode(mod_word))

        if (len(mod_word) == 0 or docx[0].is_stop):
            return None
        else:
            return docx[0].lemma_
    except:
        return None # to handle the odd case of characters like 'x02', etc.
    
if flag_print:
    test_words = ['Hello!!', '.,<>', 'India', 'of', '..freedoM..', 'e-mail']
    
    for word in test_words:
        print word, '--returned-->', modify(word)
# Out:
# Hello!! --returned--> hello
# .,<> --returned--> None
# India --returned--> india
# of --returned--> None
# ..freedoM.. --returned--> freedom
# e-mail --returned--> email

# %%
# utility function to skip line when no alphabet present
def is_bad(line):
    for c in line:
        if (c.isalpha()):
            return False
    return True
      
if flag_print:
    test_words = ['.', '<.>', 'Speak', 'out', '"Eric"', 'freemail...']
    
    for word in test_words:
        print word, '--returned-->', is_bad(word)
# Out:
# . --returned--> True
# <.> --returned--> True
# Speak --returned--> False
# out --returned--> False
# "Eric" --returned--> False
# freemail... --returned--> False

# %%
# %%time
dict_of_data_series = {}
flag_print = False

for file_name in os.listdir(os.getcwd()+'/data/CVs'):
    if flag_print:
        print '\n'
        print '*'*25
        print file_name
        print '*'*25
        
    main_file_handler = open('data/CVs/'+file_name, 'r')    
    previous_section  = 'extra'
    
    curr_data_series = pd.Series([""]*len(list_of_sections), index=list_of_sections)
                   
    for line in main_file_handler:
        # skip line if empty
        if (len(line.strip()) == 0 or is_bad(line)):
            continue
                
        # processing next line
        list_of_words_in_line = re_c.findall(line)
        list_of_imp_words_in_line  = []
        
        for i in range(len(list_of_words_in_line)):
            modified_word = modify(list_of_words_in_line[i])
            
            if (modified_word):
                list_of_imp_words_in_line.append(modified_word)

        curr_line = ' '.join(list_of_imp_words_in_line)
        doc = nlp(unicode(curr_line))
        section_value = {}
            
        # initializing section values to zero
        for section in list_of_sections:
            section_value[section] = 0.0
        section_value[None] = 0.0
            
        # updating section values    
        for token in doc:
            for section in list_of_sections:
                for word in similar_to[section]:
                    word_token = doc.vocab[unicode(word)]
                    section_value[section] = max(section_value[section], float(word_token.similarity(token)))

        # determining the next section based on section values and threshold
        most_likely_section = None
        for section in list_of_sections:
            #print '>>', section, section_value[section]
            if (section_value[most_likely_section] < section_value[section] and section_value[section] > threshold):
                most_likely_section = section
            
        # updating the section
        if (previous_section != most_likely_section and most_likely_section is not None):
            previous_section = most_likely_section
                

        # writing data to the pandas series
        try:
            docx = nlp(unicode(line))
        except:
            continue  # to handle the odd case of characters like 'x02', etc.
        mod_line = ''
        for token in docx:
            if (not token.is_stop):
                mod_line += token.lemma_ + ' '
        
        curr_data_series[previous_section] += mod_line
            
    dict_of_data_series[file_name] = curr_data_series
    if flag_print:
        print curr_data_series
    main_file_handler.close()
    
data_frame = pd.DataFrame(dict_of_data_series)
data_frame.to_csv('prc_data.csv', sep='\t')
#data_frame.head()
# Out:
# CPU times: user 56.9 s, sys: 220 ms, total: 57.1 s
# Wall time: 1min

# %%
data_frame.head()
# Out:
#                                                  cv1.txt  \
# skill  software developer - dynamix infotech \n kolka...
# extra  mahboob alam \n career objective \n personal q...
# exp    want work progressive organization utilize kno...
# edu    education \n sidho kanhu murmu university dumk...
#
#                                                     cv10  \
# skill  team member(software developer ) \n techsys so...
# extra      deepali chaudhari \n mumbai , maharashtra \n
# exp                                  work experience \n
# edu    education \n nagpur university nagpur , mahara...
#
#                                                    cv100  \
# skill  ios application developer \n software develope...
# extra  ramakrishnan k \n cuddalore , tamil nadu \n mc...
# exp    hard worker , enthusiastic , responsible , fas...
# edu    education \n \n dhanalakshmi srinivasan colleg...
#
#                                                    cv101  \
# skill  application developer \n tiruppur , tamil nadu...
# extra  jayaprakash andamuthu \n adith business pvt . ...
# exp    include design , activity working \n work expe...
# edu    education \n kongu arts science college erode ...
#
#                                                    cv102  \
# skill  application developer - cognizant technology s...
# extra  rajeev gupta \n john hancock investment projec...
# exp    * currently work cognizant technology solution...
# edu    senior solution integrator \n april 2016 augus...
#
#                                                    cv103  \
# skill  android application developer \n chennai , tam...
# extra  alaguraj ramachandran \n junior android applic...
# exp    work experience \n b.e computer science engg \...
# edu    education \n sir srnm polytechnic college satt...
#
#                                                    cv104  \
# skill  application developer - bny mellon \n coimbato...
# extra  aiswarya chandrasekaran \n new system introduc...
# exp    work experience \n project details \n 1 ) bny ...
# edu    education \n anna university chennai , tamil n...
#
#                                                    cv105  \
# skill  application developer \n bhopal , madhya prade...
# extra  ashay jain \n kpn netherlands telecom company ...
# exp    work experience \n project location groningen ...
# edu
#
#                                                    cv106  \
# skill  pursue growth experience field information tec...
# extra  heena patel \n surat , gujarat \n contribute o...
# exp                good company . \n work experience \n
# edu
#
#                                                    cv107  \
# skill  application developer - at&t \n bangalore , ka...
# extra  deba hazra \n stand - order functionality nggn...
# exp    work experience \n role : application develope...
# edu                     education \n wbut university \n
#
#                              ...                          \
# skill                        ...
# extra                        ...
# exp                          ...
# edu                          ...
#
#                                                     cv90  \
# skill  connectivity data systems , llc - chennai , ta...
# extra        karthikeyan p \n additional information \n
# exp    senior research analyst relationship science (...
# edu    data analysis : \n education \n sathyabama uni...
#
#                                                     cv91  \
# skill  skill \n microsoft excel , microsoft ppt , mic...
# extra  bishvajit bakshi \n bangalore , karnataka \n a...
# exp    work experience \n data analyst \n college , r...
# edu    education \n m.sc . statistics \n university a...
#
#                                                     cv92  \
# skill  nielsen company \n april 2015 present \n - sam...
# extra  darpana nandy \n project - linked - person \n ...
# exp    executive , data science - nielsen company \n ...
# edu    lead " evidence theory base uncertainty analys...
#
#                                                     cv93  \
# skill  tools - nlp , elasticsearch , python , alchemy...
# extra  harish venkataraman \n bangalore , karnataka \...
# exp    sufficiently expend skillset organization lear...
# edu    education \n dayananda sagar college engineeri...
#
#                                                     cv94  \
# skill  cappius technologies - hyderabad , telangana \...
# extra  sharad kakran \n link \n https://github.com/sh...
# exp    work experience \n data science intern \n c+ (...
# edu    analyze customer transaction behavior shopping...
#
#                                                     cv95  \
# skill  - extracting datum sql server 2014  \n - requi...
# extra  ketan bhatheja \n bangalore , karnataka \n - u...
# exp    work experience \n data science & analytics , ...
# edu    - data manipulation , exploratory analysis , t...
#
#                                                     cv96  \
# skill  android application developer \n adler solutio...
# extra  rahul vhayaskar \n dhule , maharashtra \n goog...
# exp    work experience \n responsibility \n understan...
# edu    education \n north maharashtra university jalg...
#
#                                                     cv97  \
# skill  android application developer \n interglobe te...
# extra  babli bisht \n additional information \n appli...
# exp    android application developer have 3.5 year ex...
# edu    education \n mtech electronics ( instrumentati...
#
#                                                     cv98  \
# skill  jr. ios application developer ( application de...
# extra  reshma patil \n link \n https://itunes.apple.c...
# exp                                  work experience \n
# edu    education \n b.e \n indira college engineering...
#
#                                                     cv99
# skill  contribute organization new trend technology \...
# extra  rajith r \n web application developer \n chenn...
# exp    dedicated work , innovative idea dynamic chall...
# edu    kodaikanal christian college - kodaikanal , ta...
#
# [4 rows x 253 columns]
